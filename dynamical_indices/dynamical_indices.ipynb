# %%
'''
dynamical_indices.ipynb 
takes in a binary file and displays out a parquet file 
identifies which particles skipped 
'''

import rebound

# %%
bin_file = "Idealsim_1Me_500DP_1000TP_10Myr.bin"

sa = rebound.Simulationarchive(bin_file)

# %%
# Out:
# <rebound.simulationarchive.Simulationarchive object at 0x10540bbd0, nblobs=50, reb_version=5.0.0>
